# %% [markdown]
# # Economic module

# %%
# load a simple model from a data directory
import openio as io
model = io.Model('C:/Users/Besitzer/Projects/openio/data_dirs/us15_2014')

# %%
print("Has make table? -> ", model.has_file(io.MAKE_TABLE))
print("Has use table? -> ", model.has_file(io.USE_TABLE))
# Out:
# Has make table? ->  True
# Has use table? ->  True

# %%
make_table = model.load_data_frame(io.MAKE_TABLE)
make_table
# Out:
#                                                     Agriculture, forestry, fishing, and hunting  \
# Agriculture, forestry, fishing, and hunting                                            488721.0
# Mining                                                                                      0.0
# Utilities                                                                                   0.0
# Construction                                                                                0.0
# Manufacturing                                                                               0.0
# Wholesale trade                                                                             0.0
# Retail trade                                                                                0.0
# Transportation and warehousing                                                              0.0
# Information                                                                                 0.0
# ...

# %%
use_table = model.load_data_frame(io.USE_TABLE)
use_table
# Out:
#                                                     Agriculture, forestry, fishing, and hunting  \
# Agriculture, forestry, fishing, and hunting                                              104837
# Mining                                                                                     2520
# Utilities                                                                                  4955
# Construction                                                                               2884
# Manufacturing                                                                             87123
# Wholesale trade                                                                           26459
# Retail trade                                                                                214
# Transportation and warehousing                                                            14260
# Information                                                                                 588
# ...

# %%
for i in make_table.columns:
    print(i)
# Out:
# Agriculture, forestry, fishing, and hunting
# Mining
# Utilities
# Construction
# Manufacturing
# Wholesale trade
# Retail trade
# Transportation and warehousing
# Information
# Finance, insurance, real estate, rental, and leasing
# Professional and business services
# Educational services, health care, and social assistance
# Arts, entertainment, recreation, accommodation, and food services
# Other services, except government
# Government
# Scrap, used and secondhand goods /1/
# Noncomparable imports and rest-of-the-world adjustment /2/
