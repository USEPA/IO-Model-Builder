# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.sankey import Sankey

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, xticks=[], yticks=[], title="Two Systems")
sankey = Sankey(ax=ax, unit=None)
sankey.add(flows=[-0.25, 0.15, 0.60], label='Mining', orientations=[1, -1, -1])

sankey.add(flows=[0.25, -0.15, 0.2], fc='#37c959', label='two',
           orientations=[-1, 1, -1], prior=0, connect=(1, 1))

sankey.add(flows=[0.1, 0.3, -0.6], fc='#37c959', label='two',
           orientations=[-1, -1, 1], prior=0, connect=(2, 2))

diagrams = sankey.finish()
diagrams[-1].patch.set_hatch('/')
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,...">
